# %%
from tensorflow import keras
import data_reader
# Out:
# 2023-10-20 16:58:30.972863: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/songye/opt/anaconda3/envs/aiffel/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
EPOCHS = 50

# %%
dr = data_reader.DataReader()
# Out:
# Data Read Done!
# Training X Size : (4128, 189)
# Training Y Size : (4128,)
# Test X Size : (1032, 189)
# Test Y Size : (1032,)

# %%
model = keras.Sequential([
    keras.layers.Embedding(8983, 128),
    keras.layers.GlobalAveragePooling1D(),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# 2023-10-20 16:58:35.836390: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(optimizer="adam", metrics=['accuracy'],
              loss="binary_crossentropy")

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f94874feb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f94874feb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 126/129 [============================>.] - ETA: 0s - loss: 0.4237 - accuracy: 0.8750WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f948777aa70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f948777aa70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 129/129 [==============================] - 3s 14ms/step - loss: 0.4218 - accuracy: 0.8752 - val_loss: 0.3692 - val_accuracy: 0.8653
# Epoch 2/50
# 129/129 [==============================] - 1s 8ms/step - loss: 0.3351 - accuracy: 0.8781 - val_loss: 0.3402 - val_accuracy: 0.8653
# Epoch 3/50
# 129/129 [==============================] - 1s 9ms/step - loss: 0.2832 - accuracy: 0.8781 - val_loss: 0.2546 - val_accuracy: 0.8653
# Epoch 4/50
# 129/129 [==============================] - 1s 11ms/step - loss: 0.1652 - accuracy: 0.9329 - val_loss: 0.1162 - val_accuracy: 0.9651
# Epoch 5/50
# 129/129 [==============================] - 1s 11ms/step - loss: 0.0783 - accuracy: 0.9782 - val_loss: 0.0738 - val_accuracy: 0.9719
# Epoch 6/50
# 129/129 [==============================] - 1s 8ms/step - loss: 0.0498 - accuracy: 0.9847 - val_loss: 0.0607 - val_accuracy: 0.9777
# Epoch 7/50
# 129/129 [==============================] - 1s 8ms/step - loss: 0.0379 - accuracy: 0.9898 - val_loss: 0.0493 - val_accuracy: 0.9913
# Epoch 8/50
# 129/129 [==============================] - 1s 10ms/step - loss: 0.0309 - accuracy: 0.9915 - val_loss: 0.0443 - val_accuracy: 0.9903
# Epoch 9/50
# 129/129 [==============================] - 1s 10ms/step - loss: 0.0251 - accuracy: 0.9930 - val_loss: 0.0431 - val_accuracy: 0.9884
# Epoch 10/50
# 129/129 [==============================] - 1s 9ms/step - loss: 0.0217 - accuracy: 0.9932 - val_loss: 0.0406 - val_accuracy: 0.9913
# Epoch 11/50
# 129/129 [==============================] - 1s 10ms/step - loss: 0.0174 - accuracy: 0.9944 - val_loss: 0.0431 - val_accuracy: 0.9884
# Epoch 12/50
# 129/129 [==============================] - 1s 10ms/step - loss: 0.0165 - accuracy: 0.9954 - val_loss: 0.0397 - val_accuracy: 0.9913
# Epoch 13/50
# 129/129 [==============================] - 1s 10ms/step - loss: 0.0117 - accuracy: 0.9971 - val_loss: 0.0395 - val_accuracy: 0.9913
# Epoch 14/50
# 129/129 [==============================] - 1s 9ms/step - loss: 0.0100 - accuracy: 0.9976 - val_loss: 0.0442 - val_accuracy: 0.9922
# Epoch 15/50
# 129/129 [==============================] - 1s 10ms/step - loss: 0.0088 - accuracy: 0.9981 - val_loss: 0.0424 - val_accuracy: 0.9913
# Epoch 16/50
# 129/129 [==============================] - 1s 11ms/step - loss: 0.0071 - accuracy: 0.9985 - val_loss: 0.0448 - val_accuracy: 0.9913
# Epoch 17/50
# 129/129 [==============================] - 1s 10ms/step - loss: 0.0072 - accuracy: 0.9983 - val_loss: 0.0497 - val_accuracy: 0.9893
# Epoch 18/50
# 129/129 [==============================] - 1s 10ms/step - loss: 0.0067 - accuracy: 0.9988 - val_loss: 0.0409 - val_accuracy: 0.9922
# Epoch 19/50
# 129/129 [==============================] - 1s 9ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0412 - val_accuracy: 0.9913
# Epoch 20/50
# 129/129 [==============================] - 1s 9ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 0.0434 - val_accuracy: 0.9913
# Epoch 21/50
# 129/129 [==============================] - 1s 9ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.0449 - val_accuracy: 0.9913
# Epoch 22/50
# 129/129 [==============================] - 1s 9ms/step - loss: 0.0042 - accuracy: 0.9993 - val_loss: 0.0545 - val_accuracy: 0.9913
# Epoch 23/50
# 129/129 [==============================] - 1s 11ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0558 - val_accuracy: 0.9903

# %%
data_reader.draw_graph(history)
