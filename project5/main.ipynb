# %%
from tensorflow import keras
import data_reader
# Out:
# 2023-10-16 15:32:19.165052: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/songye/opt/anaconda3/envs/aiffel/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
EPOCHS = 20
dr = data_reader.DataReader()
# Out:
# Data Read Done!
# Training X Size : (50000, 32, 32)
# Training Y Size : (50000, 1)
# Test X Size : (10000, 32, 32)
# Test Y Size : (10000, 1)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32, 32)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])
# Out:
# 2023-10-16 15:32:33.829695: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 132,490
# Trainable params: 132,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fd4cff3a4d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fd4cff3a4d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1547/1563 [============================>.] - ETA: 0s - loss: 2.0534 - accuracy: 0.2567WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7fd46d588cb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7fd46d588cb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0524 - accuracy: 0.2569 - val_loss: 1.9445 - val_accuracy: 0.3076
# Epoch 2/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.9202 - accuracy: 0.3151 - val_loss: 2.0089 - val_accuracy: 0.2911
# Epoch 3/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8644 - accuracy: 0.3364 - val_loss: 1.8548 - val_accuracy: 0.3410
# Epoch 4/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.8316 - accuracy: 0.3496 - val_loss: 1.8394 - val_accuracy: 0.3360
# Epoch 5/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.8071 - accuracy: 0.3600 - val_loss: 1.8539 - val_accuracy: 0.3344
# Epoch 6/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7893 - accuracy: 0.3645 - val_loss: 1.8176 - val_accuracy: 0.3546
# Epoch 7/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7736 - accuracy: 0.3718 - val_loss: 1.7952 - val_accuracy: 0.3595
# Epoch 8/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7633 - accuracy: 0.3743 - val_loss: 1.7911 - val_accuracy: 0.3624
# Epoch 9/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7533 - accuracy: 0.3778 - val_loss: 1.7730 - val_accuracy: 0.3693
# Epoch 10/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7433 - accuracy: 0.3809 - val_loss: 1.7824 - val_accuracy: 0.3653
# Epoch 11/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7340 - accuracy: 0.3843 - val_loss: 1.7586 - val_accuracy: 0.3755
# Epoch 12/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7286 - accuracy: 0.3871 - val_loss: 1.7707 - val_accuracy: 0.3695
# Epoch 13/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7209 - accuracy: 0.3900 - val_loss: 1.7383 - val_accuracy: 0.3796
# Epoch 14/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.7156 - accuracy: 0.3940 - val_loss: 1.8138 - val_accuracy: 0.3539
# Epoch 15/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.7120 - accuracy: 0.3919 - val_loss: 1.7788 - val_accuracy: 0.3645
# Epoch 16/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.7059 - accuracy: 0.3934 - val_loss: 1.7628 - val_accuracy: 0.3706
# Epoch 17/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.6990 - accuracy: 0.3972 - val_loss: 1.7725 - val_accuracy: 0.3659
# Epoch 18/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.6952 - accuracy: 0.3988 - val_loss: 1.7585 - val_accuracy: 0.3794
# Epoch 19/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.6936 - accuracy: 0.3993 - val_loss: 1.7578 - val_accuracy: 0.3707
# Epoch 20/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.6897 - accuracy: 0.3996 - val_loss: 1.7400 - val_accuracy: 0.3804

# %%
data_reader.draw_graph(history)
