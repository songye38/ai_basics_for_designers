# %%
from tensorflow import keras
import data_reader
# Out:
# 2023-10-16 15:44:03.195836: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/songye/opt/anaconda3/envs/aiffel/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
EPOCHS = 20
dr = data_reader.DataReader()
# Out:
# Data Read Done!
# Training X Size : (50000, 32, 32, 3)
# Training Y Size : (50000, 1)
# Test X Size : (10000, 32, 32, 3)
# Test Y Size : (10000, 1)

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    keras.layers.Dense(10, activation='softmax')
])
# Out:
# 2023-10-16 15:44:17.712220: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fb6d0d3c950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fb6d0d3c950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1561/1563 [============================>.] - ETA: 0s - loss: 1.5161 - accuracy: 0.4567WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7fb6b70f74d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7fb6b70f74d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1563/1563 [==============================] - 56s 35ms/step - loss: 1.5158 - accuracy: 0.4567 - val_loss: 1.2475 - val_accuracy: 0.5546
# Epoch 2/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 1.1705 - accuracy: 0.5882 - val_loss: 1.4092 - val_accuracy: 0.5212
# Epoch 3/20
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.0191 - accuracy: 0.6451 - val_loss: 0.9235 - val_accuracy: 0.6801
# Epoch 4/20
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.9235 - accuracy: 0.6811 - val_loss: 1.3916 - val_accuracy: 0.5655
# Epoch 5/20
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.8461 - accuracy: 0.7060 - val_loss: 0.9048 - val_accuracy: 0.6808
# Epoch 6/20
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.7934 - accuracy: 0.7274 - val_loss: 0.9994 - val_accuracy: 0.6705
# Epoch 7/20
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.7458 - accuracy: 0.7426 - val_loss: 0.9651 - val_accuracy: 0.6748
# Epoch 8/20
# 1563/1563 [==============================] - 76s 49ms/step - loss: 0.7026 - accuracy: 0.7584 - val_loss: 1.1041 - val_accuracy: 0.6440
# Epoch 9/20
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6666 - accuracy: 0.7668 - val_loss: 0.9353 - val_accuracy: 0.6885
# Epoch 10/20
# 1563/1563 [==============================] - 74s 48ms/step - loss: 0.6340 - accuracy: 0.7820 - val_loss: 0.8529 - val_accuracy: 0.7163
# Epoch 11/20
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.6037 - accuracy: 0.7915 - val_loss: 0.7962 - val_accuracy: 0.7421
# Epoch 12/20
# 1563/1563 [==============================] - 75s 48ms/step - loss: 0.5770 - accuracy: 0.7992 - val_loss: 0.9657 - val_accuracy: 0.7028
# Epoch 13/20
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.5471 - accuracy: 0.8076 - val_loss: 1.1566 - val_accuracy: 0.6673
# Epoch 14/20
# 1563/1563 [==============================] - 75s 48ms/step - loss: 0.5275 - accuracy: 0.8159 - val_loss: 0.7215 - val_accuracy: 0.7633
# Epoch 15/20
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.5055 - accuracy: 0.8220 - val_loss: 0.8766 - val_accuracy: 0.7286
# Epoch 16/20
# 1563/1563 [==============================] - 126s 81ms/step - loss: 0.4794 - accuracy: 0.8310 - val_loss: 0.8070 - val_accuracy: 0.7506
# Epoch 17/20
# 1563/1563 [==============================] - 100s 64ms/step - loss: 0.4652 - accuracy: 0.8366 - val_loss: 1.0306 - val_accuracy: 0.7012
# Epoch 18/20
# 1563/1563 [==============================] - 88s 56ms/step - loss: 0.4513 - accuracy: 0.8407 - val_loss: 0.7985 - val_accuracy: 0.7456
# Epoch 19/20
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.4341 - accuracy: 0.8473 - val_loss: 1.0735 - val_accuracy: 0.7021
# Epoch 20/20
# 1563/1563 [==============================] - 98s 63ms/step - loss: 0.4185 - accuracy: 0.8538 - val_loss: 0.9858 - val_accuracy: 0.7265

# %%
data_reader.draw_graph(history)
